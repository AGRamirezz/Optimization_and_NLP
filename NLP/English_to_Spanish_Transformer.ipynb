# %%
import pathlib
import random
import string
import re
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization

# %%
text_file = keras.utils.get_file(
    fname="spa-eng.zip",
    origin="http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip",
    extract=True,
)
text_file = pathlib.Path(text_file).parent / "spa-eng" / "spa.txt"
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# 2646016/2638744 [==============================] - 0s 0us/step
# 2654208/2638744 [==============================] - 0s 0us/step

# %%
with open(text_file) as f:
    lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
    eng, spa = line.split("\t")
    spa = "[start] " + spa + " [end]"
    text_pairs.append((eng, spa))

# %%
for _ in range(15):
    print(random.choice(text_pairs))
# Out:
# ("I'd like to remind you that you're under oath.", '[start] Me gustaría recordarte que estás bajo juramento. [end]')
# ('I make 100 euros per day.', '[start] Gano cien euros al día. [end]')
# ("Tom will come back. I'm sure he will.", '[start] Tom volverá. Estoy seguro de que sí. [end]')
# ("Where's your suitcase?", '[start] ¿Dónde está su maleta? [end]')
# ('One month after he had become ill, he died.', '[start] Él murió tras un mes de haberse enfermado. [end]')
# ('Those are too big.', '[start] Esos son demasiado grandes. [end]')
# ("It's a shame that you're not coming.", '[start] Es una pena que no vaya a venir. [end]')
# ('He came five minutes after the bell had rung.', '[start] Vino cinco minutos después de que el timbre hubiera sonado. [end]')
# ('Whether you agree or not, I’m going to do it.', '[start] Estés de acuerdo o no, voy a hacerlo. [end]')
# ("Don't believe what she says.", '[start] No te creas lo que dice. [end]')
# ("I won't let that happen.", '[start] No permitiré que eso ocurra. [end]')
# ('How many Christmas presents did you give this year?', '[start] ¿Cuántos regalos navideños has dado este año? [end]')
# ("It happened while I wasn't looking.", '[start] Ocurrió cuando no estaba mirando. [end]')
# ('Your pen is better than mine.', '[start] Tu bolígrafo es mejor que el mío. [end]')
# ('Smoking is not permitted here.', '[start] Aquí no se permite fumar. [end]')

# %%
random.shuffle(text_pairs)
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples
train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples : num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples :]

print(f"{len(text_pairs)} total pairs")
print(f"{len(train_pairs)} training pairs")
print(f"{len(val_pairs)} validation pairs")
print(f"{len(test_pairs)} test pairs")
# Out:
# 118964 total pairs
# 83276 training pairs
# 17844 validation pairs
# 17844 test pairs

# %%
strip_chars = string.punctuation + "¿"
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

vocab_size = 15000
sequence_length = 20
batch_size = 64


def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


eng_vectorization = TextVectorization(
    max_tokens=vocab_size, output_mode="int", output_sequence_length=sequence_length,
)
spa_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)
train_eng_texts = [pair[0] for pair in train_pairs]
train_spa_texts = [pair[1] for pair in train_pairs]
eng_vectorization.adapt(train_eng_texts)
spa_vectorization.adapt(train_spa_texts)

# %%
def format_dataset(eng, spa):
    eng = eng_vectorization(eng)
    spa = spa_vectorization(spa)
    return ({"encoder_inputs": eng, "decoder_inputs": spa[:, :-1],}, spa[:, 1:])


def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %%
for inputs, targets in train_ds.take(1):
    print(f'inputs["encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs["encoder_inputs"].shape: (64, 20)
# inputs["decoder_inputs"].shape: (64, 20)
# targets.shape: (64, 20)

# %%
##BUILD MODEL##

class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super(TransformerEncoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, mask=None):
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, tf.newaxis, :], dtype="int32")
        attention_output = self.attention(
            query=inputs, value=inputs, key=inputs, attention_mask=padding_mask
        )
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super(PositionalEmbedding, self).__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super(TransformerDecoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(latent_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, attention_mask=causal_mask
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(out_2 + proj_output)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)

# %%
embed_dim = 256
latent_dim = 2048
num_heads = 8

encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="encoder_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
encoder = keras.Model(encoder_inputs, encoder_outputs)

decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="decoder_inputs")
encoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="decoder_state_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(decoder_inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, encoded_seq_inputs)
x = layers.Dropout(0.5)(x)
decoder_outputs = layers.Dense(vocab_size, activation="softmax")(x)
decoder = keras.Model([decoder_inputs, encoded_seq_inputs], decoder_outputs)

decoder_outputs = decoder([decoder_inputs, encoder_outputs])
transformer = keras.Model(
    [encoder_inputs, decoder_inputs], decoder_outputs, name="transformer"
)

# %%
epochs = 100

transformer.summary()
transformer.compile(
    "rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
transformer.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding (Position  (None, None, 256)   3845120     ['encoder_inputs[0][0]']
#  alEmbedding)
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  transformer_encoder (Transform  (None, None, 256)   3155456     ['positional_embedding[0][0]']
#  erEncoder)
#
#  model_1 (Functional)           (None, None, 15000)  12959640    ['decoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
# ==================================================================================================
# Total params: 19,960,216
# Trainable params: 19,960,216
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 1302/1302 [==============================] - 51s 33ms/step - loss: 1.6372 - accuracy: 0.4333 - val_loss: 1.2703 - val_accuracy: 0.5277
# Epoch 2/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 1.3090 - accuracy: 0.5455 - val_loss: 1.1392 - val_accuracy: 0.5804
# Epoch 3/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 1.1712 - accuracy: 0.5871 - val_loss: 1.0693 - val_accuracy: 0.6069
# Epoch 4/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 1.0919 - accuracy: 0.6157 - val_loss: 1.0297 - val_accuracy: 0.6244
# Epoch 5/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 1.0483 - accuracy: 0.6360 - val_loss: 1.0041 - val_accuracy: 0.6388
# Epoch 6/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 1.0208 - accuracy: 0.6502 - val_loss: 0.9998 - val_accuracy: 0.6443
# Epoch 7/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.9987 - accuracy: 0.6626 - val_loss: 0.9877 - val_accuracy: 0.6505
# Epoch 8/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.9821 - accuracy: 0.6725 - val_loss: 0.9826 - val_accuracy: 0.6517
# Epoch 9/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.9662 - accuracy: 0.6819 - val_loss: 0.9805 - val_accuracy: 0.6541
# Epoch 10/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.9527 - accuracy: 0.6893 - val_loss: 0.9773 - val_accuracy: 0.6569
# Epoch 11/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.9399 - accuracy: 0.6952 - val_loss: 0.9830 - val_accuracy: 0.6552
# Epoch 12/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.9278 - accuracy: 0.7013 - val_loss: 0.9808 - val_accuracy: 0.6580
# Epoch 13/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.9160 - accuracy: 0.7072 - val_loss: 0.9794 - val_accuracy: 0.6611
# Epoch 14/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.9047 - accuracy: 0.7117 - val_loss: 0.9847 - val_accuracy: 0.6614
# Epoch 15/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8938 - accuracy: 0.7167 - val_loss: 0.9877 - val_accuracy: 0.6609
# Epoch 16/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8838 - accuracy: 0.7209 - val_loss: 0.9917 - val_accuracy: 0.6635
# Epoch 17/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8745 - accuracy: 0.7243 - val_loss: 0.9876 - val_accuracy: 0.6641
# Epoch 18/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8642 - accuracy: 0.7286 - val_loss: 0.9920 - val_accuracy: 0.6619
# Epoch 19/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8562 - accuracy: 0.7313 - val_loss: 0.9989 - val_accuracy: 0.6646
# Epoch 20/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8473 - accuracy: 0.7346 - val_loss: 1.0021 - val_accuracy: 0.6633
# Epoch 21/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8386 - accuracy: 0.7379 - val_loss: 0.9981 - val_accuracy: 0.6670
# Epoch 22/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8309 - accuracy: 0.7407 - val_loss: 1.0036 - val_accuracy: 0.6665
# Epoch 23/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8239 - accuracy: 0.7436 - val_loss: 1.0065 - val_accuracy: 0.6669
# Epoch 24/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8172 - accuracy: 0.7457 - val_loss: 1.0078 - val_accuracy: 0.6628
# Epoch 25/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8093 - accuracy: 0.7484 - val_loss: 1.0186 - val_accuracy: 0.6642
# Epoch 26/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.8019 - accuracy: 0.7512 - val_loss: 1.0179 - val_accuracy: 0.6651
# Epoch 27/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7956 - accuracy: 0.7532 - val_loss: 1.0235 - val_accuracy: 0.6651
# Epoch 28/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7897 - accuracy: 0.7554 - val_loss: 1.0172 - val_accuracy: 0.6667
# Epoch 29/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7836 - accuracy: 0.7580 - val_loss: 1.0417 - val_accuracy: 0.6578
# Epoch 30/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7767 - accuracy: 0.7603 - val_loss: 1.0361 - val_accuracy: 0.6642
# Epoch 31/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7724 - accuracy: 0.7617 - val_loss: 1.0423 - val_accuracy: 0.6591
# Epoch 32/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7671 - accuracy: 0.7638 - val_loss: 1.0379 - val_accuracy: 0.6658
# Epoch 33/100
# 1302/1302 [==============================] - 41s 32ms/step - loss: 0.7609 - accuracy: 0.7658 - val_loss: 1.0378 - val_accuracy: 0.6657
# Epoch 34/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7557 - accuracy: 0.7677 - val_loss: 1.0496 - val_accuracy: 0.6640
# Epoch 35/100
# 1302/1302 [==============================] - 41s 32ms/step - loss: 0.7507 - accuracy: 0.7695 - val_loss: 1.0390 - val_accuracy: 0.6658
# Epoch 36/100
# 1302/1302 [==============================] - 41s 32ms/step - loss: 0.7460 - accuracy: 0.7713 - val_loss: 1.0629 - val_accuracy: 0.6606
# Epoch 37/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7423 - accuracy: 0.7725 - val_loss: 1.0531 - val_accuracy: 0.6660
# Epoch 38/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7375 - accuracy: 0.7737 - val_loss: 1.0640 - val_accuracy: 0.6664
# Epoch 39/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7330 - accuracy: 0.7757 - val_loss: 1.0706 - val_accuracy: 0.6644
# Epoch 40/100
# 1302/1302 [==============================] - 41s 32ms/step - loss: 0.7280 - accuracy: 0.7771 - val_loss: 1.0687 - val_accuracy: 0.6620
# Epoch 41/100
# 1302/1302 [==============================] - 41s 32ms/step - loss: 0.7253 - accuracy: 0.7783 - val_loss: 1.0812 - val_accuracy: 0.6643
# Epoch 42/100
# 1302/1302 [==============================] - 41s 32ms/step - loss: 0.7209 - accuracy: 0.7794 - val_loss: 1.0857 - val_accuracy: 0.6628
# Epoch 43/100
# 1302/1302 [==============================] - 41s 32ms/step - loss: 0.7177 - accuracy: 0.7807 - val_loss: 1.0850 - val_accuracy: 0.6647
# Epoch 44/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7139 - accuracy: 0.7818 - val_loss: 1.1018 - val_accuracy: 0.6632
# Epoch 45/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7114 - accuracy: 0.7829 - val_loss: 1.0965 - val_accuracy: 0.6644
# Epoch 46/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7069 - accuracy: 0.7843 - val_loss: 1.1157 - val_accuracy: 0.6602
# Epoch 47/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.7034 - accuracy: 0.7853 - val_loss: 1.0951 - val_accuracy: 0.6603
# Epoch 48/100
# 1302/1302 [==============================] - 43s 33ms/step - loss: 0.7001 - accuracy: 0.7866 - val_loss: 1.1198 - val_accuracy: 0.6589
# Epoch 49/100
# 1302/1302 [==============================] - 43s 33ms/step - loss: 0.6984 - accuracy: 0.7874 - val_loss: 1.1124 - val_accuracy: 0.6589
# Epoch 50/100
# 1302/1302 [==============================] - 43s 33ms/step - loss: 0.6961 - accuracy: 0.7879 - val_loss: 1.1234 - val_accuracy: 0.6603
# Epoch 51/100
# 1302/1302 [==============================] - 43s 33ms/step - loss: 0.6951 - accuracy: 0.7885 - val_loss: 1.1124 - val_accuracy: 0.6612
# Epoch 52/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6898 - accuracy: 0.7901 - val_loss: 1.1347 - val_accuracy: 0.6602
# Epoch 53/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6886 - accuracy: 0.7906 - val_loss: 1.1301 - val_accuracy: 0.6605
# Epoch 54/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6864 - accuracy: 0.7911 - val_loss: 1.1349 - val_accuracy: 0.6595
# Epoch 55/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6831 - accuracy: 0.7925 - val_loss: 1.1429 - val_accuracy: 0.6585
# Epoch 56/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6805 - accuracy: 0.7938 - val_loss: 1.1539 - val_accuracy: 0.6566
# Epoch 57/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6782 - accuracy: 0.7941 - val_loss: 1.1506 - val_accuracy: 0.6544
# Epoch 58/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6765 - accuracy: 0.7951 - val_loss: 1.1587 - val_accuracy: 0.6569
# Epoch 59/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6740 - accuracy: 0.7958 - val_loss: 1.1637 - val_accuracy: 0.6584
# Epoch 60/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6710 - accuracy: 0.7970 - val_loss: 1.1598 - val_accuracy: 0.6564
# Epoch 61/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6691 - accuracy: 0.7973 - val_loss: 1.1478 - val_accuracy: 0.6600
# Epoch 62/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6673 - accuracy: 0.7979 - val_loss: 1.1627 - val_accuracy: 0.6593
# Epoch 63/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6667 - accuracy: 0.7984 - val_loss: 1.1587 - val_accuracy: 0.6580
# Epoch 64/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6630 - accuracy: 0.7994 - val_loss: 1.1715 - val_accuracy: 0.6571
# Epoch 65/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6619 - accuracy: 0.8001 - val_loss: 1.1745 - val_accuracy: 0.6594
# Epoch 66/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6611 - accuracy: 0.8002 - val_loss: 1.1808 - val_accuracy: 0.6582
# Epoch 67/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6592 - accuracy: 0.8005 - val_loss: 1.1862 - val_accuracy: 0.6522
# Epoch 68/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6580 - accuracy: 0.8014 - val_loss: 1.1930 - val_accuracy: 0.6528
# Epoch 69/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6557 - accuracy: 0.8020 - val_loss: 1.1898 - val_accuracy: 0.6519
# Epoch 70/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6539 - accuracy: 0.8024 - val_loss: 1.1852 - val_accuracy: 0.6571
# Epoch 71/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6530 - accuracy: 0.8028 - val_loss: 1.1754 - val_accuracy: 0.6548
# Epoch 72/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6509 - accuracy: 0.8037 - val_loss: 1.1799 - val_accuracy: 0.6593
# Epoch 73/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6495 - accuracy: 0.8044 - val_loss: 1.1923 - val_accuracy: 0.6534
# Epoch 74/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6486 - accuracy: 0.8043 - val_loss: 1.1771 - val_accuracy: 0.6595
# Epoch 75/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6483 - accuracy: 0.8046 - val_loss: 1.1989 - val_accuracy: 0.6546
# Epoch 76/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6456 - accuracy: 0.8057 - val_loss: 1.1892 - val_accuracy: 0.6560
# Epoch 77/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6443 - accuracy: 0.8062 - val_loss: 1.2068 - val_accuracy: 0.6516
# Epoch 78/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6427 - accuracy: 0.8066 - val_loss: 1.2003 - val_accuracy: 0.6582
# Epoch 79/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6441 - accuracy: 0.8060 - val_loss: 1.2052 - val_accuracy: 0.6552
# Epoch 80/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6423 - accuracy: 0.8065 - val_loss: 1.2261 - val_accuracy: 0.6593
# Epoch 81/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6401 - accuracy: 0.8073 - val_loss: 1.2270 - val_accuracy: 0.6562
# Epoch 82/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6398 - accuracy: 0.8078 - val_loss: 1.2051 - val_accuracy: 0.6577
# Epoch 83/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6382 - accuracy: 0.8079 - val_loss: 1.2422 - val_accuracy: 0.6564
# Epoch 84/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6381 - accuracy: 0.8083 - val_loss: 1.2164 - val_accuracy: 0.6572
# Epoch 85/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6367 - accuracy: 0.8085 - val_loss: 1.2210 - val_accuracy: 0.6550
# Epoch 86/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6384 - accuracy: 0.8081 - val_loss: 1.2739 - val_accuracy: 0.6316
# Epoch 87/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6366 - accuracy: 0.8084 - val_loss: 1.2244 - val_accuracy: 0.6584
# Epoch 88/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6349 - accuracy: 0.8091 - val_loss: 1.2394 - val_accuracy: 0.6437
# Epoch 89/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6357 - accuracy: 0.8090 - val_loss: 1.2457 - val_accuracy: 0.6583
# Epoch 90/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6361 - accuracy: 0.8086 - val_loss: 1.2261 - val_accuracy: 0.6504
# Epoch 91/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6359 - accuracy: 0.8088 - val_loss: 1.2518 - val_accuracy: 0.6467
# Epoch 92/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6350 - accuracy: 0.8092 - val_loss: 1.2533 - val_accuracy: 0.6499
# Epoch 93/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6337 - accuracy: 0.8093 - val_loss: 1.2220 - val_accuracy: 0.6538
# Epoch 94/100
# 1302/1302 [==============================] - 42s 33ms/step - loss: 0.6321 - accuracy: 0.8100 - val_loss: 1.2365 - val_accuracy: 0.6537
# Epoch 95/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6332 - accuracy: 0.8096 - val_loss: 1.2313 - val_accuracy: 0.6526
# Epoch 96/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6335 - accuracy: 0.8097 - val_loss: 1.2295 - val_accuracy: 0.6546
# Epoch 97/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6321 - accuracy: 0.8101 - val_loss: 1.2321 - val_accuracy: 0.6529
# Epoch 98/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6341 - accuracy: 0.8098 - val_loss: 1.2266 - val_accuracy: 0.6512
# Epoch 99/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6346 - accuracy: 0.8094 - val_loss: 1.2565 - val_accuracy: 0.6510
# Epoch 100/100
# 1302/1302 [==============================] - 42s 32ms/step - loss: 0.6357 - accuracy: 0.8087 - val_loss: 1.2404 - val_accuracy: 0.6514

# %%
#Decode Sequences Using Trained Model

spa_vocab = spa_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20


def decode_sequence(input_sentence):
    tokenized_input_sentence = eng_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = spa_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence

# %%
test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(30):
    input_sentence = random.choice(test_eng_texts)
    print(input_sentence)
    translated = decode_sequence(input_sentence)
    print(translated)
# Out:
# He was too short to get at the grapes.
# [start] Él estaba demasiado borracho para escrito [end]
# I did that all myself.
# [start] lo hice todo yo solo [end]
# He has lost his father's watch.
# [start] Él ha perdido el reloj de su padre [end]
# I expect him to come soon.
# [start] lo [UNK] de venir pronto [end]
# English is pretty hard, isn't it?
# [start] inglés es bastante difícil no [end]
# What if I fail?
# [start] y si no [UNK] [end]
# I am lighting my cigar.
# [start] estoy pasando mi me [UNK] [end]
# I helped my father water the flowers.
# [start] café los perros al [UNK] [end]
# There is no admission fee for children under five.
# [start] hay un [UNK] para los niños atrás [end]
# I'll make tea for you.
# [start] te haré [UNK] para usted [end]
# We won the bronze medal.
# [start] [UNK] usted la el [UNK] [end]
# Whatever happens, I'll stick to my principles to the bitter end.
# [start] suceda lo que pase a mis la tom lo que [UNK] [end]
# I know your mom doesn't want you to talk to me.
# [start] conozco a tu madre no quiere que [UNK] [end]
# Money does not grow on trees.
# [start] el dinero no va en la a los árboles [end]
# He will leave for the station an hour before the train leaves.
# [start] Él va a la estación en un tren antes de ir [end]
# I thought you were Tom's friend.
# [start] pensé que somos los [UNK] de tom [end]
# Everyone else is drinking beer.
# [start] todos los estudiantes están bebiendo cerveza [end]
# You don't have the guts.
# [start] no tienes los dos [UNK] [end]
# She persuaded him to do it.
# [start] ella lo convenció de hacerlo [end]
# The border is closed.
# [start] la familia está cerrada [end]
# It's time you stood on your own two feet.
# [start] es hora de que te [UNK] a mí mismo [end]
# I like L.A. better.
# [start] siempre se lo prefiero [end]
# Tom got on his motorcycle and started it up.
# [start] tom se levantó con su cámara y la empezó a [UNK] [end]
# We ran short of money.
# [start] nos lo hizo la [UNK] de dinero [end]
# We're curious.
# [start] tenemos curiosidad [end]
# We're on the way home.
# [start] estamos en la casa [end]
# I want to know what's going on out here.
# [start] quiero saber qué está pasando acá [end]
# Everybody knew her true feelings.
# [start] todos ella supiera sus padres [end]
# It's easier to teach children than to teach adults.
# [start] es más fácil uno [UNK] que la [UNK] [end]
# He called off the trip.
# [start] Él llamó al viaje [end]
